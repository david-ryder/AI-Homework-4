# %% [markdown]
# # Recurrent Neural Network Homework
#
# This is the 4th assignment for CAP 4630 and we will implement a basic RNN network and an LSTM network with Keras to solve two problems. \
# You will use **"Tasks"** and **"Hints"** to finish the work. **(Total 100 points, including 15 bonus points)** \
# You may use Machine Learning libaries like Scikit-learn for data preprocessing.
#
# **Task Overview:**
# - Implement a basic RNN network to solve time series prediction
# - Implement an LSTM network to conduct sentiment analysis

# %% [markdown]
# ## 1 - Implement Basic RNN network with Keras to predict time series##
# ### 1.1 Prepare the data (17 Points)
#
# Prepare time series data for deep neural network training.
#
# **Tasks:**
# 1. Load the given train and test data: "train.txt" and "test.txt". **(5 Points)**
# 2. Generate the **TRAIN** and **TEST** labels. **(5 Points)**
# 3. Normalize the **TRAIN** and **TEST** data with sklearn function "MinMaxScaler". **(5 Points)**
# 4. **PRINT OUT** the **TEST** data and label. **(2 Points)**
#
# **Hints:**
# 1. The length of original train data is 113 which starts from **"1949-01"** to **"1958-05"**. The length of original test data is 29, which starts from **"1958-07"** to **"1960-11"**.
# 2. Set the data types of both train and test data to "float32".
# 3. When you prepared input data X (sequences) and oupt data Y (labels), please consider the following relationship:
#     - The sequence X should be the **past 12** datapoints in the time series, i.e., observation sequence with historical window of 12. You may check the time series data and think about the reason.
#     - The label Y should be the **next 1** datapoint in the time series (one point ahead prediction).
# 4. The first 3 **TRAIN** data and label should be:
#
# - trainX[0] = [[0.02203858 &nbsp; 0.03856748 &nbsp; 0.077135 &nbsp;  0.06887051 &nbsp; 0.04683197 &nbsp; 0.08539945 &nbsp; 0.12121212 &nbsp; 0.12121212 &nbsp; 0.08815429 &nbsp; 0.04132232 &nbsp; 0.    &nbsp; 0.03856748]]
# - trainY[0] = [0.03030303]
#
# - trianX[1] = [[0.03856748 &nbsp; 0.077135 &nbsp;  0.06887051 &nbsp; 0.04683197  &nbsp; 0.08539945  &nbsp; 0.12121212  &nbsp; 0.12121212  &nbsp; 0.08815429  &nbsp; 0.04132232  &nbsp; 0.     &nbsp;  0.03856748   &nbsp; 0.03030303]]
# - trainY[1] = [0.06060606]
#
# - trainX[2] =  [[0.077135 &nbsp;  0.06887051 &nbsp; 0.04683197 &nbsp; 0.08539945 &nbsp; 0.12121212 &nbsp; 0.12121212 &nbsp; 0.08815429 &nbsp; 0.04132232 &nbsp; 0.    &nbsp;     0.03856748 &nbsp; 0.03030303 &nbsp; 0.06060606]]
# - trainY[2] = [0.10192838]
#
# 5. Apply the MinMaxScaler to both the train and test data.\
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html
#
#
# 6. After the preparation with scaler fitting, the shapes of trainX, trainY, testX, and testY are as follows:\
# trainX.shape = (101, 1, 12)\
# trainY.shape = (101,)\
# testX.shape = (17, 1, 12)\
# testY.shape = (17,)

# %%
### Import Libraries ###
import tensorflow as tf
from tensorflow import keras
from keras import layers
import random
import numpy as np

### Set random seed to ensure deterministic results
import os
seed_value = 1
os.environ['PYTHONHASHSEED']=str(seed_value)
def reset_random_seeds():
   tf.random.set_seed(seed_value)
   np.random.seed(seed_value)
   random.seed(seed_value)
reset_random_seeds()

# %%
### Prepare and Preprocess Data Here ###
from pandas import read_csv

### Design a Function to Prepare Observation Sequences and Corresponding Labels ###
def create_dataset(dataset, look_back=12):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back)]
        dataX.append(a) 
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)



### Train and Test Data Loading with float32 type ####
dataframe_train = read_csv('train.txt', usecols=[1], engine='python') # Read train.txt 
dataset_train = dataframe_train.values
dataset_train = dataset_train.astype('float32') # Specify the data type to 'float32'



### Scale Training and Test Data to [0, 1] ###
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1)) # specify the scaler
train = scaler.fit_transform(dataset_train) # fit the scaler to the training data
test = scaler.transform(dataset_train) # fit the scaler to the test data

### Training and Test Data Split ###
trainX, trainY = create_dataset(train, look_back=12)
testX, testY = create_dataset(test, look_back=12)

### Training and Test Data Reshape (to fit RNN input) ###
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
### Print Out the TEST Data and Labels Here ###
print(testX)
print(testY)
# Out:
# [[[0.02203858 0.03856748 0.077135   ... 0.04132232 0.         0.03856748]]
#
#  [[0.03856748 0.077135   0.06887051 ... 0.         0.03856748 0.03030303]]
#
#  [[0.077135   0.06887051 0.04683197 ... 0.03856748 0.03030303 0.06060606]]
#
#  ...
#
#  [[0.69421494 0.67217636 0.69146    ... 0.63911843 0.6501378  0.58953166]]
#
#  [[0.67217636 0.69146    0.87603307 ... 0.6501378  0.58953166 0.7107438 ]]
#
#  [[0.69146    0.87603307 0.9944904  ... 0.58953166 0.7107438  0.67217636]]]
# [0.03030303 0.06060606 0.10192838 0.08539945 0.05785125 0.12396696
#  0.18181819 0.18181819 0.14876035 0.0798898  0.02754822 0.09917355
#  0.11294767 0.12672177 0.20385677 0.16253445 0.18732783 0.20385677
#  0.261708   0.261708   0.2203857  0.15977961 0.11570248 0.1707989
#  0.184573   0.20936641 0.24517909 0.21212122 0.21763083 0.31404957
#  0.34710744 0.3801653  0.2892562  0.23966941 0.18732783 0.2479339
#  0.2534435  0.2534435  0.36363634 0.36088154 0.34435263 0.38292012
#  0.44077137 0.46280995 0.3663912  0.29476586 0.20936641 0.26721767
#  0.2754821  0.23140499 0.36088154 0.33884296 0.35812673 0.44077137
#  0.5454545  0.5206611  0.42699727 0.34435263 0.27272728 0.34435263
#  0.3801653  0.35537192 0.4490358  0.45454547 0.45730028 0.58126724
#  0.7162534  0.66942155 0.5730028  0.46831957 0.3663912  0.47933885
#  0.49586776 0.47658405 0.58677685 0.5757576  0.58953166 0.7438016
#  0.8512397  0.8292011  0.69146    0.55647385 0.46005508 0.55647385
#  0.58126724 0.5426997  0.69421494 0.67217636 0.69146    0.87603307
#  0.9944904  1.         0.8264463  0.66942155 0.55371904 0.63911843
#  0.6501378  0.58953166 0.7107438  0.67217636 0.7134986 ]

# %% [markdown]
# ### 1.2 - Build the RNN model (20 Points) ##
#
#
# Build an RNN model with SimpleRNN cell.
#
# **Tasks:**
# 1. Build an RNN model with 1 simple RNN layer and 1 Dense layer.  **(10 Points)**
# 2. Compile the model. **(5 Points)**
# 3. Train the model for **1000** epochs with **batch_size = 10**. **(5 Points)**
#
# **Hints:**
# 1. You may consider **tensorflow.keras.layers.SimpleRNN(unit_size=4)** to specify RNN cells.
# 2. Use loss function = 'mean_squared_error' and select **Adam** optimizer with **learning_rate=0.005** and other default settings.
# 3. After first epoch, the train loss is changed to around **0.0912**.
# 4. The model summary is as follows:
# - Total params: 73
# - Trainable params: 73
# - Non-trainable params: 0

# %%
### Build the RNN Model ###
import keras
from keras.models import Sequential

keras.backend.clear_session()

model = Sequential() # Declare Sequential class and assign it to variable "model"
model.add(keras.layers.SimpleRNN(4)) # Add a simple RNN layer with unit_size=4 in the model 
model.add(keras.layers.Dense(1)) # Add a following Dense layer with units=1 in the model

# %%
### Compile the RNN Model  ###

opt = keras.optimizers.Adam(learning_rate=0.005)
model.compile(loss='mse', optimizer=opt) # model compiled with mean_squared_error loss and adam optimizer

# %%
### Train the RNN Model  ###

model.fit(x=trainX, y=trainY.reshape(-1,1), epochs=1000, batch_size=10, verbose=2) # model fit with epoch=1000, batch_size=10; verbose=2 is optional.
model.summary() # print out model structure with model.summary()
# Out:
# Epoch 1/1000
# 11/11 - 0s - loss: 0.1343 - 441ms/epoch - 40ms/step
# Epoch 2/1000
# 11/11 - 0s - loss: 0.0506 - 7ms/epoch - 591us/step
# Epoch 3/1000
# 11/11 - 0s - loss: 0.0357 - 7ms/epoch - 591us/step
# Epoch 4/1000
# 11/11 - 0s - loss: 0.0304 - 7ms/epoch - 591us/step
# Epoch 5/1000
# 11/11 - 0s - loss: 0.0264 - 6ms/epoch - 546us/step
# Epoch 6/1000
# 11/11 - 0s - loss: 0.0225 - 6ms/epoch - 546us/step
# Epoch 7/1000
# 11/11 - 0s - loss: 0.0214 - 7ms/epoch - 591us/step
# Epoch 8/1000
# 11/11 - 0s - loss: 0.0195 - 7ms/epoch - 591us/step
# Epoch 9/1000
# 11/11 - 0s - loss: 0.0176 - 7ms/epoch - 591us/step
# Epoch 10/1000
# 11/11 - 0s - loss: 0.0165 - 6ms/epoch - 546us/step
# Epoch 11/1000
# 11/11 - 0s - loss: 0.0156 - 7ms/epoch - 591us/step
# Epoch 12/1000
# 11/11 - 0s - loss: 0.0150 - 7ms/epoch - 591us/step
# Epoch 13/1000
# 11/11 - 0s - loss: 0.0154 - 7ms/epoch - 591us/step
# Epoch 14/1000
# 11/11 - 0s - loss: 0.0142 - 6ms/epoch - 546us/step
# Epoch 15/1000
# 11/11 - 0s - loss: 0.0117 - 7ms/epoch - 591us/step
# Epoch 16/1000
# 11/11 - 0s - loss: 0.0127 - 7ms/epoch - 591us/step
# Epoch 17/1000
# 11/11 - 0s - loss: 0.0105 - 7ms/epoch - 591us/step
# Epoch 18/1000
# 11/11 - 0s - loss: 0.0098 - 6ms/epoch - 546us/step
# Epoch 19/1000
# 11/11 - 0s - loss: 0.0093 - 6ms/epoch - 546us/step
# Epoch 20/1000
# 11/11 - 0s - loss: 0.0094 - 7ms/epoch - 591us/step
# Epoch 21/1000
# 11/11 - 0s - loss: 0.0082 - 7ms/epoch - 591us/step
# Epoch 22/1000
# 11/11 - 0s - loss: 0.0079 - 7ms/epoch - 591us/step
# Epoch 23/1000
# 11/11 - 0s - loss: 0.0075 - 7ms/epoch - 591us/step
# Epoch 24/1000
# 11/11 - 0s - loss: 0.0080 - 7ms/epoch - 591us/step
# Epoch 25/1000
# 11/11 - 0s - loss: 0.0078 - 7ms/epoch - 591us/step
# Epoch 26/1000
# 11/11 - 0s - loss: 0.0069 - 6ms/epoch - 546us/step
# Epoch 27/1000
# 11/11 - 0s - loss: 0.0069 - 6ms/epoch - 546us/step
# Epoch 28/1000
# 11/11 - 0s - loss: 0.0055 - 6ms/epoch - 546us/step
# Epoch 29/1000
# 11/11 - 0s - loss: 0.0052 - 7ms/epoch - 591us/step
# Epoch 30/1000
# 11/11 - 0s - loss: 0.0050 - 7ms/epoch - 591us/step
# Epoch 31/1000
# 11/11 - 0s - loss: 0.0051 - 6ms/epoch - 546us/step
# Epoch 32/1000
# 11/11 - 0s - loss: 0.0046 - 7ms/epoch - 591us/step
# Epoch 33/1000
# 11/11 - 0s - loss: 0.0045 - 7ms/epoch - 591us/step
# Epoch 34/1000
# 11/11 - 0s - loss: 0.0045 - 7ms/epoch - 591us/step
# Epoch 35/1000
# 11/11 - 0s - loss: 0.0043 - 7ms/epoch - 637us/step
# Epoch 36/1000
# 11/11 - 0s - loss: 0.0042 - 7ms/epoch - 637us/step
# Epoch 37/1000
# 11/11 - 0s - loss: 0.0044 - 7ms/epoch - 637us/step
# Epoch 38/1000
# 11/11 - 0s - loss: 0.0039 - 7ms/epoch - 637us/step
# Epoch 39/1000
# 11/11 - 0s - loss: 0.0034 - 7ms/epoch - 591us/step
# Epoch 40/1000
# 11/11 - 0s - loss: 0.0033 - 7ms/epoch - 637us/step
# Epoch 41/1000
# 11/11 - 0s - loss: 0.0031 - 7ms/epoch - 637us/step
# Epoch 42/1000
# 11/11 - 0s - loss: 0.0031 - 7ms/epoch - 591us/step
# Epoch 43/1000
# 11/11 - 0s - loss: 0.0030 - 7ms/epoch - 591us/step
# Epoch 44/1000
# 11/11 - 0s - loss: 0.0031 - 7ms/epoch - 637us/step
# Epoch 45/1000
# 11/11 - 0s - loss: 0.0038 - 7ms/epoch - 591us/step
# Epoch 46/1000
# 11/11 - 0s - loss: 0.0030 - 7ms/epoch - 591us/step
# Epoch 47/1000
# 11/11 - 0s - loss: 0.0026 - 7ms/epoch - 637us/step
# Epoch 48/1000
# 11/11 - 0s - loss: 0.0024 - 7ms/epoch - 591us/step
# Epoch 49/1000
# 11/11 - 0s - loss: 0.0025 - 7ms/epoch - 637us/step
# Epoch 50/1000
# 11/11 - 0s - loss: 0.0023 - 7ms/epoch - 591us/step
# Epoch 51/1000
# 11/11 - 0s - loss: 0.0024 - 7ms/epoch - 637us/step
# Epoch 52/1000
# 11/11 - 0s - loss: 0.0024 - 7ms/epoch - 591us/step
# Epoch 53/1000
# 11/11 - 0s - loss: 0.0023 - 8ms/epoch - 682us/step
# Epoch 54/1000
# 11/11 - 0s - loss: 0.0021 - 7ms/epoch - 591us/step
# Epoch 55/1000
# 11/11 - 0s - loss: 0.0023 - 7ms/epoch - 637us/step
# Epoch 56/1000
# 11/11 - 0s - loss: 0.0024 - 8ms/epoch - 728us/step
# Epoch 57/1000
# 11/11 - 0s - loss: 0.0020 - 13ms/epoch - 1ms/step
# Epoch 58/1000
# 11/11 - 0s - loss: 0.0021 - 10ms/epoch - 864us/step
# Epoch 59/1000
# 11/11 - 0s - loss: 0.0019 - 8ms/epoch - 728us/step
# Epoch 60/1000
# 11/11 - 0s - loss: 0.0020 - 7ms/epoch - 637us/step
# Epoch 61/1000
# 11/11 - 0s - loss: 0.0018 - 7ms/epoch - 637us/step
# Epoch 62/1000
# 11/11 - 0s - loss: 0.0019 - 7ms/epoch - 637us/step
# Epoch 63/1000
# 11/11 - 0s - loss: 0.0019 - 7ms/epoch - 591us/step
# Epoch 64/1000
# 11/11 - 0s - loss: 0.0019 - 7ms/epoch - 637us/step
# Epoch 65/1000
# 11/11 - 0s - loss: 0.0022 - 7ms/epoch - 637us/step
# Epoch 66/1000
# 11/11 - 0s - loss: 0.0018 - 7ms/epoch - 591us/step
# Epoch 67/1000
# 11/11 - 0s - loss: 0.0019 - 8ms/epoch - 682us/step
# Epoch 68/1000
# 11/11 - 0s - loss: 0.0018 - 7ms/epoch - 637us/step
# Epoch 69/1000
# 11/11 - 0s - loss: 0.0018 - 7ms/epoch - 637us/step
# Epoch 70/1000
# 11/11 - 0s - loss: 0.0021 - 7ms/epoch - 637us/step
# Epoch 71/1000
# 11/11 - 0s - loss: 0.0020 - 7ms/epoch - 591us/step
# Epoch 72/1000
# 11/11 - 0s - loss: 0.0020 - 7ms/epoch - 637us/step
# Epoch 73/1000
# 11/11 - 0s - loss: 0.0023 - 7ms/epoch - 591us/step
# Epoch 74/1000
# 11/11 - 0s - loss: 0.0019 - 7ms/epoch - 637us/step
# Epoch 75/1000
# 11/11 - 0s - loss: 0.0017 - 7ms/epoch - 591us/step
# Epoch 76/1000
# 11/11 - 0s - loss: 0.0016 - 6ms/epoch - 546us/step
# Epoch 77/1000
# 11/11 - 0s - loss: 0.0020 - 6ms/epoch - 546us/step
# Epoch 78/1000
# 11/11 - 0s - loss: 0.0019 - 7ms/epoch - 591us/step
# Epoch 79/1000
# 11/11 - 0s - loss: 0.0016 - 7ms/epoch - 637us/step
# Epoch 80/1000
# 11/11 - 0s - loss: 0.0017 - 7ms/epoch - 591us/step
# Epoch 81/1000
# 11/11 - 0s - loss: 0.0015 - 6ms/epoch - 546us/step
# Epoch 82/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 637us/step
# Epoch 83/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 84/1000
# 11/11 - 0s - loss: 0.0017 - 6ms/epoch - 546us/step
# Epoch 85/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 86/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 87/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 88/1000
# 11/11 - 0s - loss: 0.0014 - 6ms/epoch - 546us/step
# Epoch 89/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 90/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 91/1000
# 11/11 - 0s - loss: 0.0019 - 7ms/epoch - 591us/step
# Epoch 92/1000
# 11/11 - 0s - loss: 0.0016 - 7ms/epoch - 591us/step
# Epoch 93/1000
# 11/11 - 0s - loss: 0.0016 - 6ms/epoch - 546us/step
# Epoch 94/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 95/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 96/1000
# 11/11 - 0s - loss: 0.0018 - 7ms/epoch - 591us/step
# Epoch 97/1000
# 11/11 - 0s - loss: 0.0016 - 7ms/epoch - 591us/step
# Epoch 98/1000
# 11/11 - 0s - loss: 0.0016 - 7ms/epoch - 591us/step
# Epoch 99/1000
# 11/11 - 0s - loss: 0.0018 - 7ms/epoch - 591us/step
# Epoch 100/1000
# 11/11 - 0s - loss: 0.0014 - 6ms/epoch - 546us/step
# Epoch 101/1000
# 11/11 - 0s - loss: 0.0013 - 6ms/epoch - 546us/step
# Epoch 102/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 103/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 104/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 105/1000
# 11/11 - 0s - loss: 0.0015 - 6ms/epoch - 546us/step
# Epoch 106/1000
# 11/11 - 0s - loss: 0.0017 - 7ms/epoch - 591us/step
# Epoch 107/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 108/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 109/1000
# 11/11 - 0s - loss: 0.0016 - 7ms/epoch - 637us/step
# Epoch 110/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 111/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 112/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 113/1000
# 11/11 - 0s - loss: 0.0017 - 7ms/epoch - 591us/step
# Epoch 114/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 115/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 116/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 117/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 637us/step
# Epoch 118/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 637us/step
# Epoch 119/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 120/1000
# 11/11 - 0s - loss: 0.0018 - 7ms/epoch - 591us/step
# Epoch 121/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 637us/step
# Epoch 122/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 123/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 124/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 125/1000
# 11/11 - 0s - loss: 0.0013 - 6ms/epoch - 546us/step
# Epoch 126/1000
# 11/11 - 0s - loss: 0.0012 - 8ms/epoch - 682us/step
# Epoch 127/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 128/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 637us/step
# Epoch 129/1000
# 11/11 - 0s - loss: 0.0016 - 7ms/epoch - 591us/step
# Epoch 130/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 131/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 132/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 133/1000
# 11/11 - 0s - loss: 0.0021 - 7ms/epoch - 591us/step
# Epoch 134/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 135/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 637us/step
# Epoch 136/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 137/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 138/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 139/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 140/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 141/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 142/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 637us/step
# Epoch 143/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 144/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 145/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 146/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 147/1000
# 11/11 - 0s - loss: 0.0011 - 6ms/epoch - 546us/step
# Epoch 148/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 149/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 150/1000
# 11/11 - 0s - loss: 0.0012 - 9ms/epoch - 773us/step
# Epoch 151/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 152/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 153/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 154/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 155/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 592us/step
# Epoch 156/1000
# 11/11 - 0s - loss: 0.0011 - 6ms/epoch - 584us/step
# Epoch 157/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 158/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 159/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 160/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 161/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 162/1000
# 11/11 - 0s - loss: 0.0025 - 7ms/epoch - 591us/step
# Epoch 163/1000
# 11/11 - 0s - loss: 0.0017 - 7ms/epoch - 591us/step
# Epoch 164/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 165/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 637us/step
# Epoch 166/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 167/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 168/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 169/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 170/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 171/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 172/1000
# 11/11 - 0s - loss: 0.0012 - 6ms/epoch - 546us/step
# Epoch 173/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 174/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 175/1000
# 11/11 - 0s - loss: 0.0012 - 8ms/epoch - 682us/step
# Epoch 176/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 177/1000
# 11/11 - 0s - loss: 0.0019 - 7ms/epoch - 591us/step
# Epoch 178/1000
# 11/11 - 0s - loss: 0.0021 - 7ms/epoch - 637us/step
# Epoch 179/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 180/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 181/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 182/1000
# 11/11 - 0s - loss: 0.0017 - 7ms/epoch - 591us/step
# Epoch 183/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 184/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 185/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 186/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 187/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 188/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 189/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 637us/step
# Epoch 190/1000
# 11/11 - 0s - loss: 0.0019 - 8ms/epoch - 682us/step
# Epoch 191/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 637us/step
# Epoch 192/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 193/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 194/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 637us/step
# Epoch 195/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 637us/step
# Epoch 196/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 197/1000
# 11/11 - 0s - loss: 0.0010 - 8ms/epoch - 682us/step
# Epoch 198/1000
# 11/11 - 0s - loss: 0.0011 - 9ms/epoch - 773us/step
# Epoch 199/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 200/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 201/1000
# 11/11 - 0s - loss: 0.0016 - 7ms/epoch - 591us/step
# Epoch 202/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 203/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 204/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 205/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 206/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 207/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 208/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 209/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 210/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 211/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 637us/step
# Epoch 212/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 213/1000
# 11/11 - 0s - loss: 0.0014 - 8ms/epoch - 682us/step
# Epoch 214/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 215/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 216/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 217/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 218/1000
# 11/11 - 0s - loss: 0.0016 - 7ms/epoch - 591us/step
# Epoch 219/1000
# 11/11 - 0s - loss: 0.0010 - 9ms/epoch - 773us/step
# Epoch 220/1000
# 11/11 - 0s - loss: 0.0013 - 8ms/epoch - 682us/step
# Epoch 221/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 222/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 637us/step
# Epoch 223/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 224/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 225/1000
# 11/11 - 0s - loss: 0.0011 - 6ms/epoch - 546us/step
# Epoch 226/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 227/1000
# 11/11 - 0s - loss: 0.0010 - 6ms/epoch - 546us/step
# Epoch 228/1000
# 11/11 - 0s - loss: 0.0016 - 7ms/epoch - 637us/step
# Epoch 229/1000
# 11/11 - 0s - loss: 0.0020 - 7ms/epoch - 591us/step
# Epoch 230/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 231/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 232/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 233/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 234/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 235/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 236/1000
# 11/11 - 0s - loss: 9.9890e-04 - 7ms/epoch - 591us/step
# Epoch 237/1000
# 11/11 - 0s - loss: 0.0012 - 6ms/epoch - 546us/step
# Epoch 238/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 239/1000
# 11/11 - 0s - loss: 0.0014 - 8ms/epoch - 682us/step
# Epoch 240/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 637us/step
# Epoch 241/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 242/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 243/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 244/1000
# 11/11 - 0s - loss: 9.8344e-04 - 7ms/epoch - 591us/step
# Epoch 245/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 246/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 247/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 248/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 249/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 250/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 251/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 252/1000
# 11/11 - 0s - loss: 9.7409e-04 - 7ms/epoch - 591us/step
# Epoch 253/1000
# 11/11 - 0s - loss: 9.7448e-04 - 10ms/epoch - 864us/step
# Epoch 254/1000
# 11/11 - 0s - loss: 0.0010 - 11ms/epoch - 1ms/step
# Epoch 255/1000
# 11/11 - 0s - loss: 0.0012 - 8ms/epoch - 682us/step
# Epoch 256/1000
# 11/11 - 0s - loss: 0.0012 - 9ms/epoch - 773us/step
# Epoch 257/1000
# 11/11 - 0s - loss: 0.0011 - 8ms/epoch - 728us/step
# Epoch 258/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 259/1000
# 11/11 - 0s - loss: 0.0010 - 8ms/epoch - 682us/step
# Epoch 260/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 637us/step
# Epoch 261/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 262/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 637us/step
# Epoch 263/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 264/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 265/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 266/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 267/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 268/1000
# 11/11 - 0s - loss: 0.0016 - 7ms/epoch - 637us/step
# Epoch 269/1000
# 11/11 - 0s - loss: 0.0019 - 7ms/epoch - 591us/step
# Epoch 270/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 271/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 272/1000
# 11/11 - 0s - loss: 0.0011 - 6ms/epoch - 546us/step
# Epoch 273/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 274/1000
# 11/11 - 0s - loss: 0.0021 - 8ms/epoch - 728us/step
# Epoch 275/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 276/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 277/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 278/1000
# 11/11 - 0s - loss: 0.0011 - 6ms/epoch - 546us/step
# Epoch 279/1000
# 11/11 - 0s - loss: 9.8100e-04 - 7ms/epoch - 637us/step
# Epoch 280/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 281/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 282/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 283/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 284/1000
# 11/11 - 0s - loss: 0.0018 - 7ms/epoch - 591us/step
# Epoch 285/1000
# 11/11 - 0s - loss: 0.0021 - 7ms/epoch - 591us/step
# Epoch 286/1000
# 11/11 - 0s - loss: 0.0017 - 7ms/epoch - 591us/step
# Epoch 287/1000
# 11/11 - 0s - loss: 0.0024 - 7ms/epoch - 591us/step
# Epoch 288/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 289/1000
# 11/11 - 0s - loss: 0.0019 - 7ms/epoch - 591us/step
# Epoch 290/1000
# 11/11 - 0s - loss: 0.0018 - 8ms/epoch - 682us/step
# Epoch 291/1000
# 11/11 - 0s - loss: 0.0013 - 8ms/epoch - 682us/step
# Epoch 292/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 293/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 294/1000
# 11/11 - 0s - loss: 9.7026e-04 - 7ms/epoch - 637us/step
# Epoch 295/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 296/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 297/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 298/1000
# 11/11 - 0s - loss: 9.9102e-04 - 7ms/epoch - 637us/step
# Epoch 299/1000
# 11/11 - 0s - loss: 0.0017 - 7ms/epoch - 637us/step
# Epoch 300/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 301/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 302/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 303/1000
# 11/11 - 0s - loss: 9.5934e-04 - 7ms/epoch - 637us/step
# Epoch 304/1000
# 11/11 - 0s - loss: 9.8619e-04 - 8ms/epoch - 728us/step
# Epoch 305/1000
# 11/11 - 0s - loss: 9.5153e-04 - 7ms/epoch - 637us/step
# Epoch 306/1000
# 11/11 - 0s - loss: 9.9936e-04 - 7ms/epoch - 591us/step
# Epoch 307/1000
# 11/11 - 0s - loss: 9.7240e-04 - 7ms/epoch - 591us/step
# Epoch 308/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 309/1000
# 11/11 - 0s - loss: 0.0016 - 7ms/epoch - 671us/step
# Epoch 310/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 311/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 312/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 601us/step
# Epoch 313/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 314/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 315/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 316/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 317/1000
# 11/11 - 0s - loss: 9.9633e-04 - 7ms/epoch - 591us/step
# Epoch 318/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 319/1000
# 11/11 - 0s - loss: 9.8004e-04 - 8ms/epoch - 728us/step
# Epoch 320/1000
# 11/11 - 0s - loss: 9.6541e-04 - 8ms/epoch - 682us/step
# Epoch 321/1000
# 11/11 - 0s - loss: 0.0017 - 7ms/epoch - 637us/step
# Epoch 322/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 323/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 324/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 325/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 326/1000
# 11/11 - 0s - loss: 9.6104e-04 - 7ms/epoch - 637us/step
# Epoch 327/1000
# 11/11 - 0s - loss: 9.6266e-04 - 7ms/epoch - 637us/step
# Epoch 328/1000
# 11/11 - 0s - loss: 9.7520e-04 - 7ms/epoch - 637us/step
# Epoch 329/1000
# 11/11 - 0s - loss: 0.0011 - 8ms/epoch - 728us/step
# Epoch 330/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 331/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 332/1000
# 11/11 - 0s - loss: 0.0012 - 8ms/epoch - 682us/step
# Epoch 333/1000
# 11/11 - 0s - loss: 0.0010 - 8ms/epoch - 728us/step
# Epoch 334/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 335/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 336/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 337/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 338/1000
# 11/11 - 0s - loss: 0.0020 - 7ms/epoch - 637us/step
# Epoch 339/1000
# 11/11 - 0s - loss: 0.0017 - 7ms/epoch - 637us/step
# Epoch 340/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 341/1000
# 11/11 - 0s - loss: 0.0012 - 13ms/epoch - 1ms/step
# Epoch 342/1000
# 11/11 - 0s - loss: 0.0011 - 11ms/epoch - 1ms/step
# Epoch 343/1000
# 11/11 - 0s - loss: 0.0010 - 8ms/epoch - 682us/step
# Epoch 344/1000
# 11/11 - 0s - loss: 0.0018 - 9ms/epoch - 773us/step
# Epoch 345/1000
# 11/11 - 0s - loss: 0.0013 - 8ms/epoch - 712us/step
# Epoch 346/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 347/1000
# 11/11 - 0s - loss: 0.0011 - 8ms/epoch - 682us/step
# Epoch 348/1000
# 11/11 - 0s - loss: 0.0014 - 8ms/epoch - 682us/step
# Epoch 349/1000
# 11/11 - 0s - loss: 0.0012 - 8ms/epoch - 682us/step
# Epoch 350/1000
# 11/11 - 0s - loss: 0.0021 - 7ms/epoch - 591us/step
# Epoch 351/1000
# 11/11 - 0s - loss: 0.0023 - 6ms/epoch - 546us/step
# Epoch 352/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 353/1000
# 11/11 - 0s - loss: 9.8359e-04 - 7ms/epoch - 591us/step
# Epoch 354/1000
# 11/11 - 0s - loss: 9.9768e-04 - 7ms/epoch - 591us/step
# Epoch 355/1000
# 11/11 - 0s - loss: 9.3754e-04 - 7ms/epoch - 591us/step
# Epoch 356/1000
# 11/11 - 0s - loss: 9.7952e-04 - 7ms/epoch - 637us/step
# Epoch 357/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 358/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 359/1000
# 11/11 - 0s - loss: 0.0016 - 7ms/epoch - 591us/step
# Epoch 360/1000
# 11/11 - 0s - loss: 9.8065e-04 - 8ms/epoch - 728us/step
# Epoch 361/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 362/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 637us/step
# Epoch 363/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 364/1000
# 11/11 - 0s - loss: 9.8829e-04 - 7ms/epoch - 591us/step
# Epoch 365/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 366/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 367/1000
# 11/11 - 0s - loss: 9.9831e-04 - 7ms/epoch - 591us/step
# Epoch 368/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 369/1000
# 11/11 - 0s - loss: 0.0016 - 6ms/epoch - 546us/step
# Epoch 370/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 637us/step
# Epoch 371/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 372/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 373/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 374/1000
# 11/11 - 0s - loss: 0.0016 - 8ms/epoch - 728us/step
# Epoch 375/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 376/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 377/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 378/1000
# 11/11 - 0s - loss: 0.0018 - 7ms/epoch - 637us/step
# Epoch 379/1000
# 11/11 - 0s - loss: 0.0019 - 7ms/epoch - 591us/step
# Epoch 380/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 381/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 382/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 383/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 384/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 385/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 386/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 387/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 388/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 389/1000
# 11/11 - 0s - loss: 9.0775e-04 - 7ms/epoch - 591us/step
# Epoch 390/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 391/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 392/1000
# 11/11 - 0s - loss: 9.5122e-04 - 7ms/epoch - 637us/step
# Epoch 393/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 394/1000
# 11/11 - 0s - loss: 9.5058e-04 - 7ms/epoch - 591us/step
# Epoch 395/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 602us/step
# Epoch 396/1000
# 11/11 - 0s - loss: 9.3156e-04 - 7ms/epoch - 591us/step
# Epoch 397/1000
# 11/11 - 0s - loss: 9.5347e-04 - 7ms/epoch - 591us/step
# Epoch 398/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 399/1000
# 11/11 - 0s - loss: 0.0010 - 8ms/epoch - 682us/step
# Epoch 400/1000
# 11/11 - 0s - loss: 0.0010 - 6ms/epoch - 546us/step
# Epoch 401/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 402/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 403/1000
# 11/11 - 0s - loss: 9.7102e-04 - 7ms/epoch - 591us/step
# Epoch 404/1000
# 11/11 - 0s - loss: 0.0012 - 10ms/epoch - 864us/step
# Epoch 405/1000
# 11/11 - 0s - loss: 0.0014 - 10ms/epoch - 910us/step
# Epoch 406/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 407/1000
# 11/11 - 0s - loss: 0.0011 - 9ms/epoch - 773us/step
# Epoch 408/1000
# 11/11 - 0s - loss: 9.4534e-04 - 7ms/epoch - 591us/step
# Epoch 409/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 410/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 637us/step
# Epoch 411/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 412/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 413/1000
# 11/11 - 0s - loss: 0.0014 - 9ms/epoch - 773us/step
# Epoch 414/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 415/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 416/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 417/1000
# 11/11 - 0s - loss: 0.0023 - 7ms/epoch - 637us/step
# Epoch 418/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 419/1000
# 11/11 - 0s - loss: 9.6095e-04 - 7ms/epoch - 637us/step
# Epoch 420/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 421/1000
# 11/11 - 0s - loss: 9.0000e-04 - 7ms/epoch - 637us/step
# Epoch 422/1000
# 11/11 - 0s - loss: 9.2815e-04 - 8ms/epoch - 682us/step
# Epoch 423/1000
# 11/11 - 0s - loss: 9.3301e-04 - 7ms/epoch - 637us/step
# Epoch 424/1000
# 11/11 - 0s - loss: 9.4898e-04 - 7ms/epoch - 637us/step
# Epoch 425/1000
# 11/11 - 0s - loss: 9.9499e-04 - 8ms/epoch - 728us/step
# Epoch 426/1000
# 11/11 - 0s - loss: 0.0012 - 8ms/epoch - 682us/step
# Epoch 427/1000
# 11/11 - 0s - loss: 9.9423e-04 - 7ms/epoch - 591us/step
# Epoch 428/1000
# 11/11 - 0s - loss: 9.5284e-04 - 7ms/epoch - 591us/step
# Epoch 429/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 592us/step
# Epoch 430/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 431/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 432/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 637us/step
# Epoch 433/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 434/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 435/1000
# 11/11 - 0s - loss: 9.8333e-04 - 7ms/epoch - 637us/step
# Epoch 436/1000
# 11/11 - 0s - loss: 0.0010 - 10ms/epoch - 910us/step
# Epoch 437/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 438/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 592us/step
# Epoch 439/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 440/1000
# 11/11 - 0s - loss: 0.0010 - 8ms/epoch - 728us/step
# Epoch 441/1000
# 11/11 - 0s - loss: 9.4343e-04 - 14ms/epoch - 1ms/step
# Epoch 442/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 443/1000
# 11/11 - 0s - loss: 0.0011 - 8ms/epoch - 682us/step
# Epoch 444/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 445/1000
# 11/11 - 0s - loss: 0.0010 - 8ms/epoch - 682us/step
# Epoch 446/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 447/1000
# 11/11 - 0s - loss: 9.4223e-04 - 8ms/epoch - 682us/step
# Epoch 448/1000
# 11/11 - 0s - loss: 0.0015 - 8ms/epoch - 728us/step
# Epoch 449/1000
# 11/11 - 0s - loss: 0.0011 - 8ms/epoch - 728us/step
# Epoch 450/1000
# 11/11 - 0s - loss: 0.0010 - 8ms/epoch - 682us/step
# Epoch 451/1000
# 11/11 - 0s - loss: 9.2800e-04 - 8ms/epoch - 728us/step
# Epoch 452/1000
# 11/11 - 0s - loss: 9.9173e-04 - 8ms/epoch - 682us/step
# Epoch 453/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 454/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 637us/step
# Epoch 455/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 456/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 457/1000
# 11/11 - 0s - loss: 0.0016 - 8ms/epoch - 682us/step
# Epoch 458/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 459/1000
# 11/11 - 0s - loss: 0.0018 - 8ms/epoch - 682us/step
# Epoch 460/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 461/1000
# 11/11 - 0s - loss: 0.0010 - 11ms/epoch - 955us/step
# Epoch 462/1000
# 11/11 - 0s - loss: 0.0010 - 10ms/epoch - 910us/step
# Epoch 463/1000
# 11/11 - 0s - loss: 9.6825e-04 - 7ms/epoch - 637us/step
# Epoch 464/1000
# 11/11 - 0s - loss: 9.9907e-04 - 9ms/epoch - 819us/step
# Epoch 465/1000
# 11/11 - 0s - loss: 9.5255e-04 - 7ms/epoch - 637us/step
# Epoch 466/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 467/1000
# 11/11 - 0s - loss: 9.4580e-04 - 7ms/epoch - 637us/step
# Epoch 468/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 469/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 470/1000
# 11/11 - 0s - loss: 0.0011 - 8ms/epoch - 728us/step
# Epoch 471/1000
# 11/11 - 0s - loss: 0.0012 - 8ms/epoch - 682us/step
# Epoch 472/1000
# 11/11 - 0s - loss: 0.0016 - 7ms/epoch - 637us/step
# Epoch 473/1000
# 11/11 - 0s - loss: 9.5272e-04 - 7ms/epoch - 637us/step
# Epoch 474/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 475/1000
# 11/11 - 0s - loss: 9.4470e-04 - 7ms/epoch - 637us/step
# Epoch 476/1000
# 11/11 - 0s - loss: 9.2843e-04 - 7ms/epoch - 591us/step
# Epoch 477/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 637us/step
# Epoch 478/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 479/1000
# 11/11 - 0s - loss: 0.0012 - 8ms/epoch - 728us/step
# Epoch 480/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 481/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 637us/step
# Epoch 482/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 483/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 484/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 485/1000
# 11/11 - 0s - loss: 9.3324e-04 - 7ms/epoch - 591us/step
# Epoch 486/1000
# 11/11 - 0s - loss: 9.8237e-04 - 7ms/epoch - 591us/step
# Epoch 487/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 488/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 489/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 490/1000
# 11/11 - 0s - loss: 0.0011 - 9ms/epoch - 773us/step
# Epoch 491/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 492/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 493/1000
# 11/11 - 0s - loss: 9.2270e-04 - 7ms/epoch - 637us/step
# Epoch 494/1000
# 11/11 - 0s - loss: 9.7583e-04 - 7ms/epoch - 637us/step
# Epoch 495/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 496/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 497/1000
# 11/11 - 0s - loss: 9.1795e-04 - 8ms/epoch - 682us/step
# Epoch 498/1000
# 11/11 - 0s - loss: 9.7200e-04 - 7ms/epoch - 637us/step
# Epoch 499/1000
# 11/11 - 0s - loss: 0.0016 - 9ms/epoch - 773us/step
# Epoch 500/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 501/1000
# 11/11 - 0s - loss: 0.0012 - 8ms/epoch - 682us/step
# Epoch 502/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 503/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 504/1000
# 11/11 - 0s - loss: 0.0017 - 8ms/epoch - 682us/step
# Epoch 505/1000
# 11/11 - 0s - loss: 0.0017 - 7ms/epoch - 637us/step
# Epoch 506/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 637us/step
# Epoch 507/1000
# 11/11 - 0s - loss: 9.9457e-04 - 8ms/epoch - 682us/step
# Epoch 508/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 509/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 510/1000
# 11/11 - 0s - loss: 0.0014 - 8ms/epoch - 682us/step
# Epoch 511/1000
# 11/11 - 0s - loss: 9.7000e-04 - 8ms/epoch - 728us/step
# Epoch 512/1000
# 11/11 - 0s - loss: 9.7235e-04 - 11ms/epoch - 955us/step
# Epoch 513/1000
# 11/11 - 0s - loss: 9.5986e-04 - 10ms/epoch - 864us/step
# Epoch 514/1000
# 11/11 - 0s - loss: 0.0010 - 8ms/epoch - 682us/step
# Epoch 515/1000
# 11/11 - 0s - loss: 0.0011 - 8ms/epoch - 682us/step
# Epoch 516/1000
# 11/11 - 0s - loss: 9.1634e-04 - 7ms/epoch - 591us/step
# Epoch 517/1000
# 11/11 - 0s - loss: 0.0017 - 7ms/epoch - 637us/step
# Epoch 518/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 519/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 637us/step
# Epoch 520/1000
# 11/11 - 0s - loss: 9.7129e-04 - 6ms/epoch - 546us/step
# Epoch 521/1000
# 11/11 - 0s - loss: 9.6032e-04 - 7ms/epoch - 591us/step
# Epoch 522/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 523/1000
# 11/11 - 0s - loss: 0.0013 - 8ms/epoch - 728us/step
# Epoch 524/1000
# 11/11 - 0s - loss: 0.0013 - 8ms/epoch - 682us/step
# Epoch 525/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 637us/step
# Epoch 526/1000
# 11/11 - 0s - loss: 9.2922e-04 - 7ms/epoch - 591us/step
# Epoch 527/1000
# 11/11 - 0s - loss: 9.6777e-04 - 7ms/epoch - 591us/step
# Epoch 528/1000
# 11/11 - 0s - loss: 9.5126e-04 - 7ms/epoch - 637us/step
# Epoch 529/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 530/1000
# 11/11 - 0s - loss: 0.0011 - 8ms/epoch - 728us/step
# Epoch 531/1000
# 11/11 - 0s - loss: 0.0015 - 8ms/epoch - 682us/step
# Epoch 532/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 533/1000
# 11/11 - 0s - loss: 9.4939e-04 - 7ms/epoch - 637us/step
# Epoch 534/1000
# 11/11 - 0s - loss: 9.6788e-04 - 8ms/epoch - 682us/step
# Epoch 535/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 536/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 537/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 538/1000
# 11/11 - 0s - loss: 9.5688e-04 - 7ms/epoch - 591us/step
# Epoch 539/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 540/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 541/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 637us/step
# Epoch 542/1000
# 11/11 - 0s - loss: 0.0016 - 7ms/epoch - 637us/step
# Epoch 543/1000
# 11/11 - 0s - loss: 0.0014 - 9ms/epoch - 819us/step
# Epoch 544/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 545/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 610us/step
# Epoch 546/1000
# 11/11 - 0s - loss: 9.8210e-04 - 7ms/epoch - 637us/step
# Epoch 547/1000
# 11/11 - 0s - loss: 9.4633e-04 - 7ms/epoch - 591us/step
# Epoch 548/1000
# 11/11 - 0s - loss: 9.7007e-04 - 7ms/epoch - 591us/step
# Epoch 549/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 550/1000
# 11/11 - 0s - loss: 9.5994e-04 - 7ms/epoch - 637us/step
# Epoch 551/1000
# 11/11 - 0s - loss: 9.9941e-04 - 7ms/epoch - 591us/step
# Epoch 552/1000
# 11/11 - 0s - loss: 9.2564e-04 - 14ms/epoch - 1ms/step
# Epoch 553/1000
# 11/11 - 0s - loss: 9.2602e-04 - 13ms/epoch - 1ms/step
# Epoch 554/1000
# 11/11 - 0s - loss: 9.3815e-04 - 8ms/epoch - 728us/step
# Epoch 555/1000
# 11/11 - 0s - loss: 9.6879e-04 - 8ms/epoch - 728us/step
# Epoch 556/1000
# 11/11 - 0s - loss: 9.4549e-04 - 7ms/epoch - 637us/step
# Epoch 557/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 558/1000
# 11/11 - 0s - loss: 0.0011 - 8ms/epoch - 682us/step
# Epoch 559/1000
# 11/11 - 0s - loss: 9.5660e-04 - 7ms/epoch - 637us/step
# Epoch 560/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 561/1000
# 11/11 - 0s - loss: 9.4556e-04 - 7ms/epoch - 591us/step
# Epoch 562/1000
# 11/11 - 0s - loss: 9.7204e-04 - 9ms/epoch - 773us/step
# Epoch 563/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 564/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 565/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 566/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 567/1000
# 11/11 - 0s - loss: 9.8095e-04 - 7ms/epoch - 591us/step
# Epoch 568/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 569/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 570/1000
# 11/11 - 0s - loss: 9.9198e-04 - 7ms/epoch - 637us/step
# Epoch 571/1000
# 11/11 - 0s - loss: 9.5699e-04 - 7ms/epoch - 591us/step
# Epoch 572/1000
# 11/11 - 0s - loss: 0.0011 - 8ms/epoch - 728us/step
# Epoch 573/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 574/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 637us/step
# Epoch 575/1000
# 11/11 - 0s - loss: 9.7450e-04 - 7ms/epoch - 591us/step
# Epoch 576/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 577/1000
# 11/11 - 0s - loss: 0.0010 - 8ms/epoch - 682us/step
# Epoch 578/1000
# 11/11 - 0s - loss: 9.8092e-04 - 8ms/epoch - 682us/step
# Epoch 579/1000
# 11/11 - 0s - loss: 9.2905e-04 - 8ms/epoch - 682us/step
# Epoch 580/1000
# 11/11 - 0s - loss: 9.5261e-04 - 8ms/epoch - 682us/step
# Epoch 581/1000
# 11/11 - 0s - loss: 9.4912e-04 - 10ms/epoch - 910us/step
# Epoch 582/1000
# 11/11 - 0s - loss: 9.0290e-04 - 8ms/epoch - 682us/step
# Epoch 583/1000
# 11/11 - 0s - loss: 9.1678e-04 - 7ms/epoch - 637us/step
# Epoch 584/1000
# 11/11 - 0s - loss: 9.0020e-04 - 7ms/epoch - 637us/step
# Epoch 585/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 586/1000
# 11/11 - 0s - loss: 9.0970e-04 - 7ms/epoch - 637us/step
# Epoch 587/1000
# 11/11 - 0s - loss: 8.9596e-04 - 7ms/epoch - 591us/step
# Epoch 588/1000
# 11/11 - 0s - loss: 0.0012 - 8ms/epoch - 728us/step
# Epoch 589/1000
# 11/11 - 0s - loss: 0.0013 - 8ms/epoch - 728us/step
# Epoch 590/1000
# 11/11 - 0s - loss: 0.0011 - 8ms/epoch - 682us/step
# Epoch 591/1000
# 11/11 - 0s - loss: 0.0010 - 8ms/epoch - 682us/step
# Epoch 592/1000
# 11/11 - 0s - loss: 9.2507e-04 - 9ms/epoch - 773us/step
# Epoch 593/1000
# 11/11 - 0s - loss: 9.1875e-04 - 12ms/epoch - 1ms/step
# Epoch 594/1000
# 11/11 - 0s - loss: 8.8385e-04 - 15ms/epoch - 1ms/step
# Epoch 595/1000
# 11/11 - 0s - loss: 0.0010 - 8ms/epoch - 682us/step
# Epoch 596/1000
# 11/11 - 0s - loss: 0.0012 - 8ms/epoch - 728us/step
# Epoch 597/1000
# 11/11 - 0s - loss: 0.0010 - 8ms/epoch - 682us/step
# Epoch 598/1000
# 11/11 - 0s - loss: 9.0256e-04 - 7ms/epoch - 637us/step
# Epoch 599/1000
# 11/11 - 0s - loss: 9.1647e-04 - 7ms/epoch - 637us/step
# Epoch 600/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 601/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 602/1000
# 11/11 - 0s - loss: 9.7629e-04 - 9ms/epoch - 773us/step
# Epoch 603/1000
# 11/11 - 0s - loss: 0.0011 - 8ms/epoch - 728us/step
# Epoch 604/1000
# 11/11 - 0s - loss: 0.0014 - 8ms/epoch - 682us/step
# Epoch 605/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 606/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 607/1000
# 11/11 - 0s - loss: 9.9681e-04 - 8ms/epoch - 682us/step
# Epoch 608/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 609/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 610/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 611/1000
# 11/11 - 0s - loss: 8.9442e-04 - 8ms/epoch - 682us/step
# Epoch 612/1000
# 11/11 - 0s - loss: 9.5275e-04 - 7ms/epoch - 637us/step
# Epoch 613/1000
# 11/11 - 0s - loss: 9.5787e-04 - 7ms/epoch - 591us/step
# Epoch 614/1000
# 11/11 - 0s - loss: 0.0016 - 7ms/epoch - 637us/step
# Epoch 615/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 616/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 617/1000
# 11/11 - 0s - loss: 0.0015 - 8ms/epoch - 728us/step
# Epoch 618/1000
# 11/11 - 0s - loss: 0.0011 - 8ms/epoch - 728us/step
# Epoch 619/1000
# 11/11 - 0s - loss: 8.9923e-04 - 7ms/epoch - 637us/step
# Epoch 620/1000
# 11/11 - 0s - loss: 8.8383e-04 - 7ms/epoch - 591us/step
# Epoch 621/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 622/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 637us/step
# Epoch 623/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 624/1000
# 11/11 - 0s - loss: 0.0018 - 7ms/epoch - 591us/step
# Epoch 625/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 626/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 627/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 637us/step
# Epoch 628/1000
# 11/11 - 0s - loss: 0.0018 - 7ms/epoch - 591us/step
# Epoch 629/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 630/1000
# 11/11 - 0s - loss: 9.3808e-04 - 7ms/epoch - 637us/step
# Epoch 631/1000
# 11/11 - 0s - loss: 9.5257e-04 - 9ms/epoch - 819us/step
# Epoch 632/1000
# 11/11 - 0s - loss: 9.1009e-04 - 10ms/epoch - 910us/step
# Epoch 633/1000
# 11/11 - 0s - loss: 0.0010 - 8ms/epoch - 682us/step
# Epoch 634/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 635/1000
# 11/11 - 0s - loss: 0.0010 - 8ms/epoch - 682us/step
# Epoch 636/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 637/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 638/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 639/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 637us/step
# Epoch 640/1000
# 11/11 - 0s - loss: 9.7031e-04 - 7ms/epoch - 591us/step
# Epoch 641/1000
# 11/11 - 0s - loss: 9.3970e-04 - 7ms/epoch - 591us/step
# Epoch 642/1000
# 11/11 - 0s - loss: 9.2539e-04 - 7ms/epoch - 591us/step
# Epoch 643/1000
# 11/11 - 0s - loss: 8.9286e-04 - 7ms/epoch - 637us/step
# Epoch 644/1000
# 11/11 - 0s - loss: 9.5643e-04 - 6ms/epoch - 546us/step
# Epoch 645/1000
# 11/11 - 0s - loss: 0.0012 - 6ms/epoch - 546us/step
# Epoch 646/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 647/1000
# 11/11 - 0s - loss: 9.6050e-04 - 7ms/epoch - 591us/step
# Epoch 648/1000
# 11/11 - 0s - loss: 9.2226e-04 - 7ms/epoch - 591us/step
# Epoch 649/1000
# 11/11 - 0s - loss: 0.0015 - 6ms/epoch - 546us/step
# Epoch 650/1000
# 11/11 - 0s - loss: 9.8773e-04 - 7ms/epoch - 591us/step
# Epoch 651/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 652/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 653/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 654/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 655/1000
# 11/11 - 0s - loss: 0.0019 - 6ms/epoch - 546us/step
# Epoch 656/1000
# 11/11 - 0s - loss: 0.0016 - 6ms/epoch - 546us/step
# Epoch 657/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 658/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 659/1000
# 11/11 - 0s - loss: 9.1154e-04 - 7ms/epoch - 637us/step
# Epoch 660/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 661/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 662/1000
# 11/11 - 0s - loss: 0.0013 - 8ms/epoch - 682us/step
# Epoch 663/1000
# 11/11 - 0s - loss: 0.0011 - 8ms/epoch - 682us/step
# Epoch 664/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 665/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 666/1000
# 11/11 - 0s - loss: 9.4077e-04 - 7ms/epoch - 637us/step
# Epoch 667/1000
# 11/11 - 0s - loss: 9.9698e-04 - 7ms/epoch - 637us/step
# Epoch 668/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 669/1000
# 11/11 - 0s - loss: 9.8016e-04 - 7ms/epoch - 591us/step
# Epoch 670/1000
# 11/11 - 0s - loss: 9.1761e-04 - 7ms/epoch - 591us/step
# Epoch 671/1000
# 11/11 - 0s - loss: 9.2944e-04 - 6ms/epoch - 546us/step
# Epoch 672/1000
# 11/11 - 0s - loss: 9.9722e-04 - 6ms/epoch - 546us/step
# Epoch 673/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 674/1000
# 11/11 - 0s - loss: 9.1720e-04 - 7ms/epoch - 591us/step
# Epoch 675/1000
# 11/11 - 0s - loss: 0.0010 - 10ms/epoch - 910us/step
# Epoch 676/1000
# 11/11 - 0s - loss: 0.0012 - 8ms/epoch - 728us/step
# Epoch 677/1000
# 11/11 - 0s - loss: 0.0012 - 8ms/epoch - 728us/step
# Epoch 678/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 679/1000
# 11/11 - 0s - loss: 9.9881e-04 - 6ms/epoch - 546us/step
# Epoch 680/1000
# 11/11 - 0s - loss: 9.0882e-04 - 6ms/epoch - 546us/step
# Epoch 681/1000
# 11/11 - 0s - loss: 9.0890e-04 - 6ms/epoch - 546us/step
# Epoch 682/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 683/1000
# 11/11 - 0s - loss: 0.0011 - 6ms/epoch - 546us/step
# Epoch 684/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 685/1000
# 11/11 - 0s - loss: 9.7164e-04 - 6ms/epoch - 546us/step
# Epoch 686/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 687/1000
# 11/11 - 0s - loss: 9.1733e-04 - 7ms/epoch - 591us/step
# Epoch 688/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 689/1000
# 11/11 - 0s - loss: 0.0017 - 6ms/epoch - 546us/step
# Epoch 690/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 691/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 692/1000
# 11/11 - 0s - loss: 9.7050e-04 - 7ms/epoch - 591us/step
# Epoch 693/1000
# 11/11 - 0s - loss: 9.4697e-04 - 7ms/epoch - 591us/step
# Epoch 694/1000
# 11/11 - 0s - loss: 0.0014 - 6ms/epoch - 546us/step
# Epoch 695/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 696/1000
# 11/11 - 0s - loss: 9.4715e-04 - 7ms/epoch - 637us/step
# Epoch 697/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 698/1000
# 11/11 - 0s - loss: 0.0017 - 7ms/epoch - 591us/step
# Epoch 699/1000
# 11/11 - 0s - loss: 0.0018 - 7ms/epoch - 591us/step
# Epoch 700/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 701/1000
# 11/11 - 0s - loss: 9.5360e-04 - 7ms/epoch - 637us/step
# Epoch 702/1000
# 11/11 - 0s - loss: 9.3830e-04 - 7ms/epoch - 591us/step
# Epoch 703/1000
# 11/11 - 0s - loss: 9.2760e-04 - 7ms/epoch - 591us/step
# Epoch 704/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 705/1000
# 11/11 - 0s - loss: 9.7297e-04 - 7ms/epoch - 637us/step
# Epoch 706/1000
# 11/11 - 0s - loss: 9.3670e-04 - 7ms/epoch - 591us/step
# Epoch 707/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 708/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 709/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 710/1000
# 11/11 - 0s - loss: 8.8997e-04 - 7ms/epoch - 637us/step
# Epoch 711/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 712/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 713/1000
# 11/11 - 0s - loss: 0.0017 - 7ms/epoch - 591us/step
# Epoch 714/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 715/1000
# 11/11 - 0s - loss: 0.0012 - 13ms/epoch - 1ms/step
# Epoch 716/1000
# 11/11 - 0s - loss: 0.0013 - 12ms/epoch - 1ms/step
# Epoch 717/1000
# 11/11 - 0s - loss: 9.1817e-04 - 8ms/epoch - 728us/step
# Epoch 718/1000
# 11/11 - 0s - loss: 0.0010 - 8ms/epoch - 682us/step
# Epoch 719/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 720/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# ...
# Epoch 777/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 778/1000
# 11/11 - 0s - loss: 9.0532e-04 - 7ms/epoch - 637us/step
# Epoch 779/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 780/1000
# 11/11 - 0s - loss: 9.1706e-04 - 7ms/epoch - 591us/step
# Epoch 781/1000
# 11/11 - 0s - loss: 9.9507e-04 - 7ms/epoch - 637us/step
# Epoch 782/1000
# 11/11 - 0s - loss: 9.0651e-04 - 7ms/epoch - 637us/step
# Epoch 783/1000
# 11/11 - 0s - loss: 0.0011 - 11ms/epoch - 955us/step
# Epoch 784/1000
# 11/11 - 0s - loss: 8.9587e-04 - 13ms/epoch - 1ms/step
# Epoch 785/1000
# 11/11 - 0s - loss: 9.1504e-04 - 9ms/epoch - 773us/step
# Epoch 786/1000
# 11/11 - 0s - loss: 8.4357e-04 - 8ms/epoch - 728us/step
# Epoch 787/1000
# 11/11 - 0s - loss: 9.8907e-04 - 7ms/epoch - 637us/step
# Epoch 788/1000
# 11/11 - 0s - loss: 8.8079e-04 - 7ms/epoch - 637us/step
# Epoch 789/1000
# 11/11 - 0s - loss: 9.6830e-04 - 7ms/epoch - 636us/step
# Epoch 790/1000
# 11/11 - 0s - loss: 9.0254e-04 - 7ms/epoch - 591us/step
# Epoch 791/1000
# 11/11 - 0s - loss: 9.5432e-04 - 7ms/epoch - 637us/step
# Epoch 792/1000
# 11/11 - 0s - loss: 9.9760e-04 - 7ms/epoch - 591us/step
# Epoch 793/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 637us/step
# Epoch 794/1000
# 11/11 - 0s - loss: 9.6995e-04 - 7ms/epoch - 637us/step
# Epoch 795/1000
# 11/11 - 0s - loss: 8.9486e-04 - 7ms/epoch - 637us/step
# Epoch 796/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 797/1000
# 11/11 - 0s - loss: 0.0010 - 8ms/epoch - 682us/step
# Epoch 798/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 637us/step
# Epoch 799/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 800/1000
# 11/11 - 0s - loss: 9.8981e-04 - 7ms/epoch - 591us/step
# Epoch 801/1000
# 11/11 - 0s - loss: 9.1736e-04 - 7ms/epoch - 591us/step
# Epoch 802/1000
# 11/11 - 0s - loss: 9.9144e-04 - 7ms/epoch - 591us/step
# Epoch 803/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 804/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 805/1000
# 11/11 - 0s - loss: 8.4427e-04 - 7ms/epoch - 637us/step
# Epoch 806/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 807/1000
# 11/11 - 0s - loss: 9.1238e-04 - 8ms/epoch - 728us/step
# Epoch 808/1000
# 11/11 - 0s - loss: 9.3678e-04 - 7ms/epoch - 637us/step
# Epoch 809/1000
# 11/11 - 0s - loss: 9.2731e-04 - 9ms/epoch - 773us/step
# Epoch 810/1000
# 11/11 - 0s - loss: 8.8259e-04 - 7ms/epoch - 591us/step
# Epoch 811/1000
# 11/11 - 0s - loss: 8.8979e-04 - 7ms/epoch - 591us/step
# Epoch 812/1000
# 11/11 - 0s - loss: 9.0313e-04 - 10ms/epoch - 864us/step
# Epoch 813/1000
# 11/11 - 0s - loss: 8.9547e-04 - 12ms/epoch - 1ms/step
# Epoch 814/1000
# 11/11 - 0s - loss: 8.9886e-04 - 8ms/epoch - 728us/step
# Epoch 815/1000
# 11/11 - 0s - loss: 9.3736e-04 - 9ms/epoch - 773us/step
# Epoch 816/1000
# 11/11 - 0s - loss: 0.0010 - 8ms/epoch - 682us/step
# Epoch 817/1000
# 11/11 - 0s - loss: 0.0010 - 8ms/epoch - 682us/step
# Epoch 818/1000
# 11/11 - 0s - loss: 8.8089e-04 - 7ms/epoch - 637us/step
# Epoch 819/1000
# 11/11 - 0s - loss: 9.7842e-04 - 7ms/epoch - 637us/step
# Epoch 820/1000
# 11/11 - 0s - loss: 8.6463e-04 - 7ms/epoch - 637us/step
# Epoch 821/1000
# 11/11 - 0s - loss: 8.6426e-04 - 7ms/epoch - 591us/step
# Epoch 822/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 823/1000
# 11/11 - 0s - loss: 9.2177e-04 - 7ms/epoch - 591us/step
# Epoch 824/1000
# 11/11 - 0s - loss: 9.6409e-04 - 6ms/epoch - 546us/step
# Epoch 825/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 637us/step
# Epoch 826/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 827/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 592us/step
# Epoch 828/1000
# 11/11 - 0s - loss: 9.5399e-04 - 7ms/epoch - 591us/step
# Epoch 829/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 830/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 831/1000
# 11/11 - 0s - loss: 9.4739e-04 - 7ms/epoch - 591us/step
# Epoch 832/1000
# 11/11 - 0s - loss: 9.4036e-04 - 7ms/epoch - 591us/step
# Epoch 833/1000
# 11/11 - 0s - loss: 9.8868e-04 - 7ms/epoch - 591us/step
# Epoch 834/1000
# 11/11 - 0s - loss: 9.5292e-04 - 7ms/epoch - 637us/step
# Epoch 835/1000
# 11/11 - 0s - loss: 9.3519e-04 - 7ms/epoch - 591us/step
# Epoch 836/1000
# 11/11 - 0s - loss: 9.0368e-04 - 6ms/epoch - 546us/step
# Epoch 837/1000
# 11/11 - 0s - loss: 9.2927e-04 - 7ms/epoch - 591us/step
# Epoch 838/1000
# 11/11 - 0s - loss: 8.7755e-04 - 7ms/epoch - 637us/step
# Epoch 839/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 637us/step
# Epoch 840/1000
# 11/11 - 0s - loss: 8.9837e-04 - 7ms/epoch - 591us/step
# Epoch 841/1000
# 11/11 - 0s - loss: 9.7460e-04 - 7ms/epoch - 637us/step
# Epoch 842/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 843/1000
# 11/11 - 0s - loss: 8.8543e-04 - 7ms/epoch - 591us/step
# Epoch 844/1000
# 11/11 - 0s - loss: 0.0018 - 7ms/epoch - 637us/step
# Epoch 845/1000
# 11/11 - 0s - loss: 9.6778e-04 - 7ms/epoch - 591us/step
# Epoch 846/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 847/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 848/1000
# 11/11 - 0s - loss: 8.5295e-04 - 6ms/epoch - 546us/step
# Epoch 849/1000
# 11/11 - 0s - loss: 0.0023 - 6ms/epoch - 546us/step
# Epoch 850/1000
# 11/11 - 0s - loss: 0.0016 - 7ms/epoch - 591us/step
# Epoch 851/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 852/1000
# 11/11 - 0s - loss: 0.0011 - 6ms/epoch - 546us/step
# Epoch 853/1000
# 11/11 - 0s - loss: 9.1394e-04 - 6ms/epoch - 546us/step
# Epoch 854/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 855/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 856/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 857/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 858/1000
# 11/11 - 0s - loss: 9.0002e-04 - 6ms/epoch - 546us/step
# Epoch 859/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 860/1000
# 11/11 - 0s - loss: 9.1057e-04 - 7ms/epoch - 591us/step
# Epoch 861/1000
# 11/11 - 0s - loss: 0.0011 - 6ms/epoch - 546us/step
# Epoch 862/1000
# 11/11 - 0s - loss: 0.0012 - 10ms/epoch - 864us/step
# Epoch 863/1000
# 11/11 - 0s - loss: 9.5915e-04 - 9ms/epoch - 819us/step
# Epoch 864/1000
# 11/11 - 0s - loss: 0.0010 - 8ms/epoch - 728us/step
# Epoch 865/1000
# 11/11 - 0s - loss: 9.4130e-04 - 7ms/epoch - 637us/step
# Epoch 866/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 867/1000
# 11/11 - 0s - loss: 0.0012 - 6ms/epoch - 546us/step
# Epoch 868/1000
# 11/11 - 0s - loss: 9.6890e-04 - 7ms/epoch - 637us/step
# Epoch 869/1000
# 11/11 - 0s - loss: 9.1571e-04 - 7ms/epoch - 591us/step
# Epoch 870/1000
# 11/11 - 0s - loss: 9.0718e-04 - 7ms/epoch - 591us/step
# Epoch 871/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 872/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 873/1000
# 11/11 - 0s - loss: 8.6005e-04 - 7ms/epoch - 637us/step
# Epoch 874/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 875/1000
# 11/11 - 0s - loss: 9.8849e-04 - 7ms/epoch - 591us/step
# Epoch 876/1000
# 11/11 - 0s - loss: 9.0192e-04 - 7ms/epoch - 591us/step
# Epoch 877/1000
# 11/11 - 0s - loss: 0.0014 - 7ms/epoch - 591us/step
# Epoch 878/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 591us/step
# Epoch 879/1000
# 11/11 - 0s - loss: 0.0013 - 7ms/epoch - 637us/step
# Epoch 880/1000
# 11/11 - 0s - loss: 9.5411e-04 - 7ms/epoch - 591us/step
# Epoch 881/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 882/1000
# 11/11 - 0s - loss: 9.5146e-04 - 7ms/epoch - 591us/step
# Epoch 883/1000
# 11/11 - 0s - loss: 0.0018 - 6ms/epoch - 546us/step
# Epoch 884/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 885/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 886/1000
# 11/11 - 0s - loss: 9.2497e-04 - 7ms/epoch - 591us/step
# Epoch 887/1000
# 11/11 - 0s - loss: 8.2394e-04 - 7ms/epoch - 591us/step
# Epoch 888/1000
# 11/11 - 0s - loss: 9.0116e-04 - 7ms/epoch - 591us/step
# Epoch 889/1000
# 11/11 - 0s - loss: 0.0010 - 6ms/epoch - 546us/step
# Epoch 890/1000
# 11/11 - 0s - loss: 0.0015 - 6ms/epoch - 546us/step
# Epoch 891/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 892/1000
# 11/11 - 0s - loss: 9.1017e-04 - 7ms/epoch - 591us/step
# Epoch 893/1000
# 11/11 - 0s - loss: 9.0045e-04 - 7ms/epoch - 591us/step
# Epoch 894/1000
# 11/11 - 0s - loss: 0.0012 - 6ms/epoch - 546us/step
# Epoch 895/1000
# 11/11 - 0s - loss: 9.0164e-04 - 6ms/epoch - 546us/step
# Epoch 896/1000
# 11/11 - 0s - loss: 9.8565e-04 - 7ms/epoch - 591us/step
# Epoch 897/1000
# 11/11 - 0s - loss: 8.6055e-04 - 7ms/epoch - 591us/step
# Epoch 898/1000
# 11/11 - 0s - loss: 9.4771e-04 - 7ms/epoch - 591us/step
# Epoch 899/1000
# 11/11 - 0s - loss: 8.6782e-04 - 7ms/epoch - 591us/step
# Epoch 900/1000
# 11/11 - 0s - loss: 9.2795e-04 - 7ms/epoch - 591us/step
# Epoch 901/1000
# 11/11 - 0s - loss: 8.4851e-04 - 7ms/epoch - 591us/step
# Epoch 902/1000
# 11/11 - 0s - loss: 8.5183e-04 - 7ms/epoch - 591us/step
# Epoch 903/1000
# 11/11 - 0s - loss: 8.5204e-04 - 7ms/epoch - 591us/step
# Epoch 904/1000
# 11/11 - 0s - loss: 8.9402e-04 - 7ms/epoch - 591us/step
# Epoch 905/1000
# 11/11 - 0s - loss: 9.9255e-04 - 7ms/epoch - 591us/step
# Epoch 906/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 907/1000
# 11/11 - 0s - loss: 8.9087e-04 - 6ms/epoch - 546us/step
# Epoch 908/1000
# 11/11 - 0s - loss: 9.4276e-04 - 7ms/epoch - 591us/step
# Epoch 909/1000
# 11/11 - 0s - loss: 8.9437e-04 - 7ms/epoch - 591us/step
# Epoch 910/1000
# 11/11 - 0s - loss: 8.7110e-04 - 8ms/epoch - 728us/step
# Epoch 911/1000
# 11/11 - 0s - loss: 9.4446e-04 - 9ms/epoch - 773us/step
# Epoch 912/1000
# 11/11 - 0s - loss: 0.0011 - 9ms/epoch - 773us/step
# Epoch 913/1000
# 11/11 - 0s - loss: 0.0013 - 8ms/epoch - 728us/step
# Epoch 914/1000
# 11/11 - 0s - loss: 0.0019 - 7ms/epoch - 591us/step
# Epoch 915/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 592us/step
# Epoch 916/1000
# 11/11 - 0s - loss: 0.0011 - 6ms/epoch - 546us/step
# Epoch 917/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 918/1000
# 11/11 - 0s - loss: 9.8436e-04 - 6ms/epoch - 546us/step
# Epoch 919/1000
# 11/11 - 0s - loss: 0.0010 - 6ms/epoch - 546us/step
# Epoch 920/1000
# 11/11 - 0s - loss: 9.6823e-04 - 6ms/epoch - 546us/step
# Epoch 921/1000
# 11/11 - 0s - loss: 8.7367e-04 - 7ms/epoch - 591us/step
# Epoch 922/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 923/1000
# 11/11 - 0s - loss: 8.9708e-04 - 6ms/epoch - 546us/step
# Epoch 924/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 925/1000
# 11/11 - 0s - loss: 8.9680e-04 - 7ms/epoch - 591us/step
# Epoch 926/1000
# 11/11 - 0s - loss: 9.1906e-04 - 6ms/epoch - 546us/step
# Epoch 927/1000
# 11/11 - 0s - loss: 8.5773e-04 - 7ms/epoch - 591us/step
# Epoch 928/1000
# 11/11 - 0s - loss: 8.4768e-04 - 7ms/epoch - 591us/step
# Epoch 929/1000
# 11/11 - 0s - loss: 8.7011e-04 - 7ms/epoch - 591us/step
# Epoch 930/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 931/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 932/1000
# 11/11 - 0s - loss: 0.0010 - 6ms/epoch - 546us/step
# Epoch 933/1000
# 11/11 - 0s - loss: 9.2464e-04 - 6ms/epoch - 546us/step
# Epoch 934/1000
# 11/11 - 0s - loss: 8.8734e-04 - 6ms/epoch - 546us/step
# Epoch 935/1000
# 11/11 - 0s - loss: 0.0010 - 6ms/epoch - 546us/step
# Epoch 936/1000
# 11/11 - 0s - loss: 8.9465e-04 - 7ms/epoch - 591us/step
# Epoch 937/1000
# 11/11 - 0s - loss: 9.9688e-04 - 7ms/epoch - 591us/step
# Epoch 938/1000
# 11/11 - 0s - loss: 9.7787e-04 - 7ms/epoch - 591us/step
# Epoch 939/1000
# 11/11 - 0s - loss: 8.5879e-04 - 7ms/epoch - 591us/step
# Epoch 940/1000
# 11/11 - 0s - loss: 0.0010 - 7ms/epoch - 591us/step
# Epoch 941/1000
# 11/11 - 0s - loss: 9.8559e-04 - 6ms/epoch - 546us/step
# Epoch 942/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 943/1000
# 11/11 - 0s - loss: 0.0010 - 6ms/epoch - 546us/step
# Epoch 944/1000
# 11/11 - 0s - loss: 8.9470e-04 - 6ms/epoch - 546us/step
# Epoch 945/1000
# 11/11 - 0s - loss: 9.2361e-04 - 7ms/epoch - 591us/step
# Epoch 946/1000
# 11/11 - 0s - loss: 9.4480e-04 - 7ms/epoch - 591us/step
# Epoch 947/1000
# 11/11 - 0s - loss: 0.0012 - 6ms/epoch - 563us/step
# Epoch 948/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 949/1000
# 11/11 - 0s - loss: 8.6272e-04 - 7ms/epoch - 591us/step
# Epoch 950/1000
# 11/11 - 0s - loss: 8.9570e-04 - 7ms/epoch - 591us/step
# Epoch 951/1000
# 11/11 - 0s - loss: 8.8100e-04 - 7ms/epoch - 637us/step
# Epoch 952/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 953/1000
# 11/11 - 0s - loss: 8.7950e-04 - 7ms/epoch - 591us/step
# Epoch 954/1000
# 11/11 - 0s - loss: 8.7328e-04 - 7ms/epoch - 591us/step
# Epoch 955/1000
# 11/11 - 0s - loss: 0.0011 - 6ms/epoch - 546us/step
# Epoch 956/1000
# 11/11 - 0s - loss: 8.8628e-04 - 8ms/epoch - 728us/step
# Epoch 957/1000
# 11/11 - 0s - loss: 9.1259e-04 - 9ms/epoch - 773us/step
# Epoch 958/1000
# 11/11 - 0s - loss: 8.6390e-04 - 7ms/epoch - 637us/step
# Epoch 959/1000
# 11/11 - 0s - loss: 0.0012 - 8ms/epoch - 728us/step
# Epoch 960/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 961/1000
# 11/11 - 0s - loss: 0.0011 - 6ms/epoch - 546us/step
# Epoch 962/1000
# 11/11 - 0s - loss: 8.7164e-04 - 6ms/epoch - 546us/step
# Epoch 963/1000
# 11/11 - 0s - loss: 0.0012 - 6ms/epoch - 546us/step
# Epoch 964/1000
# 11/11 - 0s - loss: 0.0010 - 6ms/epoch - 546us/step
# Epoch 965/1000
# 11/11 - 0s - loss: 9.4862e-04 - 6ms/epoch - 546us/step
# Epoch 966/1000
# 11/11 - 0s - loss: 8.5008e-04 - 6ms/epoch - 546us/step
# Epoch 967/1000
# 11/11 - 0s - loss: 9.3956e-04 - 7ms/epoch - 591us/step
# Epoch 968/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 969/1000
# 11/11 - 0s - loss: 0.0015 - 7ms/epoch - 591us/step
# Epoch 970/1000
# 11/11 - 0s - loss: 0.0012 - 7ms/epoch - 591us/step
# Epoch 971/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 972/1000
# 11/11 - 0s - loss: 9.8089e-04 - 7ms/epoch - 637us/step
# Epoch 973/1000
# 11/11 - 0s - loss: 9.6646e-04 - 7ms/epoch - 591us/step
# Epoch 974/1000
# 11/11 - 0s - loss: 8.5404e-04 - 7ms/epoch - 591us/step
# Epoch 975/1000
# 11/11 - 0s - loss: 0.0016 - 6ms/epoch - 546us/step
# Epoch 976/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 977/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 978/1000
# 11/11 - 0s - loss: 9.7984e-04 - 7ms/epoch - 591us/step
# Epoch 979/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 591us/step
# Epoch 980/1000
# 11/11 - 0s - loss: 9.9456e-04 - 7ms/epoch - 591us/step
# Epoch 981/1000
# 11/11 - 0s - loss: 8.9138e-04 - 7ms/epoch - 602us/step
# Epoch 982/1000
# 11/11 - 0s - loss: 0.0012 - 6ms/epoch - 546us/step
# Epoch 983/1000
# 11/11 - 0s - loss: 8.4468e-04 - 7ms/epoch - 591us/step
# Epoch 984/1000
# 11/11 - 0s - loss: 9.4807e-04 - 6ms/epoch - 546us/step
# Epoch 985/1000
# 11/11 - 0s - loss: 8.3228e-04 - 7ms/epoch - 591us/step
# Epoch 986/1000
# 11/11 - 0s - loss: 9.4752e-04 - 7ms/epoch - 591us/step
# Epoch 987/1000
# 11/11 - 0s - loss: 8.0071e-04 - 7ms/epoch - 591us/step
# Epoch 988/1000
# 11/11 - 0s - loss: 9.6655e-04 - 7ms/epoch - 591us/step
# Epoch 989/1000
# 11/11 - 0s - loss: 8.8116e-04 - 7ms/epoch - 591us/step
# Epoch 990/1000
# 11/11 - 0s - loss: 8.3496e-04 - 7ms/epoch - 591us/step
# Epoch 991/1000
# 11/11 - 0s - loss: 8.6995e-04 - 6ms/epoch - 546us/step
# Epoch 992/1000
# 11/11 - 0s - loss: 8.7996e-04 - 7ms/epoch - 591us/step
# Epoch 993/1000
# 11/11 - 0s - loss: 0.0010 - 9ms/epoch - 773us/step
# Epoch 994/1000
# 11/11 - 0s - loss: 0.0011 - 10ms/epoch - 910us/step
# Epoch 995/1000
# 11/11 - 0s - loss: 9.3923e-04 - 8ms/epoch - 728us/step
# Epoch 996/1000
# 11/11 - 0s - loss: 9.7289e-04 - 7ms/epoch - 637us/step
# Epoch 997/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 998/1000
# 11/11 - 0s - loss: 9.3555e-04 - 7ms/epoch - 591us/step
# Epoch 999/1000
# 11/11 - 0s - loss: 0.0011 - 7ms/epoch - 637us/step
# Epoch 1000/1000
# 11/11 - 0s - loss: 9.8087e-04 - 7ms/epoch - 627us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 4)                 68
#
#  dense (Dense)               (None, 1)                 5
#
# =================================================================
# Total params: 73
# Trainable params: 73
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 1.3 Evaluate Predictive Model Performance (10 Points)
#
# Predict datapoints with the observed datapoints and trained model.
#
# **Tasks:**
# 1. Do direct prediction on train and test datapoints with the obtained model in section 1.2. **(2 Points)**
# 2. Scale the prediction results back to original representation with the scaler.(scaler.inverse_transform function) **(3 Points)**
# 3. Calculate root mean squared error (RMSE) and **print out** the error for **both TRAIN and TEST**. **(3 Points)**
# 4. **Plot** the **TEST** label and prediction. **(2 Points)**
#
#
# **Hints:**
# 1. Scale back the predictions with the build-in function "scaler.inverse_transform".\
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html#sklearn.preprocessing.MinMaxScaler.inverse_transform
# 2. For validation: Train Score: **~10.92 RMSE** Test Score: **~27.70 RMSE**
# 3. The plot for validation is shown below (observation test data are blue and prediction results are orange):
#
#
# ![](https://drive.google.com/uc?export=view&id=10c1Fsa_9v0AQf2fDpCzGPFPxbIEso81u)

# %%
### Make Predictions ###

trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# Out:
# 4/4 [==============================] - 0s 834us/step
# 4/4 [==============================] - 0s 834us/step

# %%
### Scale Back Predictions ###
trainY = np.squeeze(trainY)
testY = np.squeeze(testY)

trainPredict = scaler.inverse_transform(trainPredict.reshape(-1, 1)) # scale train prediction back with scaler.inverse_transform()
trainY = scaler.inverse_transform([trainY])  # scale train labels back with scaler.inverse_transform()

testPredict = scaler.inverse_transform(testPredict) # scale test prediction back with scaler.inverse_transform()
testY = scaler.inverse_transform([testY]) # scale test labels back with scaler.inverse_transform()

# %%
### Calculate Root Mean Squared Error (RMSE) ###
import math
from sklearn.metrics import mean_squared_error # Import mean_squared_error from sklearn.metrics

trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0])) 
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0])) 
print('Train Score: %.2f RMSE' % (trainScore))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 11.76 RMSE
# Test Score: 11.76 RMSE

# %%
### Plot Observation Data and Prediction Results with TEST dataset ###

import matplotlib.pyplot as plt
plt.plot(testY[0]) # Plot Observations in Test Set
plt.plot(testPredict) # Plot Predictions in Test Set

plt.show()

# %% [markdown]
# ## 2 - Build an LSTM model to conduct sentiment analysis ##
#
# ### 2.1 Prepare the data (13 Points) ###
#
# Prepare IMDB data for reccurent neural network training.
#
# **Tasks:**
# 1. Load the data from IMDB review dataset and **print out** the lengths of sequences. **(3 Points)**
# 2. Preprocess review data to meet the network input requirement by specifying **number of words=1000**, setting **the analysis length of the review = 100**, and **padding the input sequences**. **(10 Points)**
#
# **Hints:**
# 1. You may load the IMDB data with keras.datasets.imdb.load_data(num_words=max_features). Here. max_features is set to **1000**.
# 2. You may use keras.preprocessing.sequence.pad_sequences(x_train, maxlen) to pad the input sequences and set maxlen to **100**.
#
# **Note:**\
# We train the built LSTM-based model with ALL training data; the **validation set** (aka **development set**) is set with the **testing set** for model evaluation. This split is common in the application with limited sampled observation data, like NLP problems.

# %%
import tensorflow as tf
import keras
from keras import layers
import random
import numpy as np


### Set random seed to ensure deterministic results
import os
seed_value = 1
os.environ['PYTHONHASHSEED']=str(seed_value)
def reset_random_seeds():
   tf.random.set_seed(seed_value)
   np.random.seed(seed_value)
   random.seed(seed_value)

reset_random_seeds() # randomly set initial data

# %%
# Prepare the data here

max_features = 1000 # Only consider the top 1k words
maxlen = 100 # Only consider the first 100 words of each movie review

(x_train, y_train), (x_val, y_val) = keras.datasets.imdb.load_data(num_words=max_features) # load IMDB data with specified num_words = 1000; testing set is set to validation set.
print(len(x_train), "Training sequences")
print(len(x_val), "Validation sequences")
x_train = keras.utils.data_utils.pad_sequences(x_train, maxlen=maxlen) # Pad IMDB training data with specified maxlen=100
x_val = keras.utils.data_utils.pad_sequences(x_val, maxlen=maxlen) # Pad IMDB validation data with specified maxlen=100
# Out:
# 25000 Training sequences
# 25000 Validation sequences

# %% [markdown]
# ### 2.2 - Design and train LSTM model (25 Points) ###
#
# Build an LSTM model.
#
# **Tasks:**
# 1. Build the LSTM model with **1 embedding layer**, **1 LSTM layer**, and **1 Dense layer**. **Print out** model summary. The embedding vector is specified with the dimension of **8**. **(10 Points)**
# 2. Compile the LSTM model with **Adam** optimizer, **binary_crossentropy** loss function, and **accuracy** metrics. **(5 Points)**
# 3. Train the LSTM model with **batch_size=64 for 10 epochs** and report **training and validation accuracies over epochs**. **(5 Points)**
# 4. **Print out** best validation accuracy. **(5 Points)**
#
#
#
# **Hints:**
# 1. Set input dimension to **1000** and output dimension to **8** for embedding layer.
# 2. Set **unit_size=8** for LSTM layer.
# 3. Set activation function to **sigmoid** for Dense layer.
# 4. For validation: the outputs for first epoch might be like （but not need to be exactly） the statistics below:\
# - **- loss: 0.5679 - accuracy: 0.7068 - val_loss: 0.4441 - val_accuracy: 0.8072**
# 5. The model summary is as follows:
# - Total params: 8,553
# - Trainable params: 8,553
# - Non-trainable params: 0
#
# **Useful Reference:**
# 1. https://keras.io/examples/nlp/bidirectional_lstm_imdb/

# %%
### Model design with Embedding and LSTM layers ####
inputs = keras.Input(shape=(None,), dtype="int32") # This is an easy way to set an adaptive length for input sequence
x = layers.Embedding(input_dim=1000, output_dim=8)(inputs) # Embed data in an 8-dimensional vector
x = layers.LSTM(units=8)(x) # Add 1st layer of LSTM with 8 hidden states (aka units)
outputs = layers.Dense(units=1, activation='sigmoid')(x) # Add a classifier with units=1 and activation="sigmoid"

### Clear cached model to refresh memory and build new model for training ###
keras.backend.clear_session() # Clear cached model
model = keras.Model(inputs, outputs) # Build new keras model
model.summary() # Print out model summary

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy']) # Compile built model with "adam", "binary_crossentropy", and metrics=["accuracy"]
model.fit(x_train, y_train, batch_size=64, epochs=10) # Train the compiled model with model.fit()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None)]            0
#
#  embedding (Embedding)       (None, None, 8)           8000
#
#  lstm (LSTM)                 (None, 8)                 544
#
#  dense (Dense)               (None, 1)                 9
#
# =================================================================
# Total params: 8,553
# Trainable params: 8,553
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 6s 13ms/step - loss: 0.5520 - accuracy: 0.7217
# Epoch 2/10
# 391/391 [==============================] - 5s 13ms/step - loss: 0.4001 - accuracy: 0.8242
# Epoch 3/10
# 391/391 [==============================] - 5s 13ms/step - loss: 0.3727 - accuracy: 0.8344
# Epoch 4/10
# 391/391 [==============================] - 5s 12ms/step - loss: 0.3597 - accuracy: 0.8423
# Epoch 5/10
# 391/391 [==============================] - 5s 12ms/step - loss: 0.3521 - accuracy: 0.8451
# Epoch 6/10
# 391/391 [==============================] - 5s 12ms/step - loss: 0.3495 - accuracy: 0.8468
# Epoch 7/10
# 391/391 [==============================] - 5s 13ms/step - loss: 0.3422 - accuracy: 0.8463
# Epoch 8/10
# 391/391 [==============================] - 5s 13ms/step - loss: 0.3373 - accuracy: 0.8505
# Epoch 9/10
# 391/391 [==============================] - 5s 13ms/step - loss: 0.3331 - accuracy: 0.8507
# Epoch 10/10
# 391/391 [==============================] - 5s 13ms/step - loss: 0.3278 - accuracy: 0.8540

# %% [markdown]
# ### 2.3 - LSTM hyperparameter tuning (Bonus 15 Points) ###
#
# Boost the performance of obtained LSTM (aka vanilla model) by hyperparameter tuning.
#
# **Tasks:**
# Note:
# - All modificiations are directly conducted based on the vanilla model above (from 2.2).
# - For each scenario, **report <span style="color:red"> BEST Validation Accuracy </span> and generate Training/Validation <span style="color:red"> Accuracy plots over epochs</span>**. You may just paste the plot figures in the cells with **Markdown mode**, or leave the result after running. **Make sure it is already correctly shown in your submitted file.**
# 1.  Scenario 1 (**5 points**):
#     - Add one additional LSTM layer (totally 2 LSTM layers).
#     - Modify the embedding dimension to 16.
#     - Modify the units of LSTM to 16.
# 2. Scenario 2 (**5 points**)
#     - Add one additional LSTM layer (totally 2 LSTM layers).
#     - Modify the embedding dimension to 128.
#     - Modify the units of LSTM to 128.
# 3. Scenario 3 (**5 points**)
#     - Add one additional LSTM layer (totally 2 LSTM layers).
#     - Modify the embedding dimension to 128.
#     - Modify the units of LSTM to 128.
#     - Increase analysis length for review data to maxlen = 200
#
# **Hints:**
# For validation: the outputs for first few epoches might be like （but not need to be exactly） the statistics below:
# - Scenario 1: **loss: 0.4968 - accuracy: 0.7450 - val_loss: 0.4079 - val_accuracy: 0.8198**
# - Scenario 2: **loss: 0.3883 - accuracy: 0.8286 - val_loss: 0.3844 - val_accuracy: 0.8242**
# - Scenario 3: **loss: 0.3688 - accuracy: 0.8382 - val_loss: 0.3692 - val_accuracy: 0.8333**
#
# - Summary of Model 1: Total params: 20,241; Trainable params: 20,241; Non-trainable params: 0
# - Summary of Model 2: Total params: 391,297; Trainable params: 391,297; Non-trainable params: 0
# - Summary of Model 3: Total params: 391,297; Trainable params: 391,297; Non-trainable params: 0
#
# You may follow the example from the reference below to add additional LSTM layer.
#
# **Useful Reference:**
# 1. https://keras.io/examples/nlp/bidirectional_lstm_imdb/

# %%
########################### Scenario 1 ###########################
##################################################################

### Set random seed to ensure deterministic results ###
import os
seed_value = 1
os.environ['PYTHONHASHSEED']=str(seed_value)
def reset_random_seeds():
   tf.random.set_seed(seed_value)
   np.random.seed(seed_value)
   random.seed(seed_value)

reset_random_seeds() # randomly set initial data

# max_features =  # Only consider the top 1k words
# maxlen =  # Only consider the first 100 words of each movie review

### Model design with Embedding and LSTM layers ####
# inputs = keras.Input(shape=(None,), dtype="int32") # This is an easy way to set an adaptive length for input sequence
# x = layers.Embedding( )(inputs) # Embed data in a 16-dimensional vector
# x = layers.LSTM( )(x) # Add 1st layer of LSTM with 16 hidden states (aka units); set return_sequences=true.
# x = layers.LSTM( )(x) # Add 2nd layer of LSTM with 16 hidden states (aka units)
# outputs = layers.Dense( )(x) # Add a classifier with units=1 and activation="sigmoid"

### Clear cached model to refresh memory and build new model for training ###
keras.backend.clear_session() # Clear cached model
# model = keras.Model(inputs, outputs) # Build new keras model
# model.summary() # Print out model summary

# model.compile( ) # Compile built model with "adam", "binary_crossentropy", and metrics=["accuracy"]
# model.fit( ) # Train the compiled model using model.fit() with batch_size=64, epochs=10, and validation_data=(x_val, y_val)

# %%
########################### Scenario 2 ###########################
##################################################################

### Set random seed to ensure deterministic results ###
import os
seed_value = 1
os.environ['PYTHONHASHSEED']=str(seed_value)
def reset_random_seeds():
   tf.random.set_seed(seed_value)
   np.random.seed(seed_value)
   random.seed(seed_value)

reset_random_seeds() # randomly set initial data

# max_features =   # Only consider the top 1k words
# maxlen =  # Only consider the first 100 words of each movie review

### Model design with Embedding and LSTM layers ####
# inputs = keras.Input(shape=(None,), dtype="int32") # This is an easy way to set an adaptive length for input sequence
# x = layers.Embedding( )(inputs) # Embed data in a 128-dimensional vector
# x = layers.LSTM( )(x) # Add 1st layer of LSTM with 128 hidden states (aka units); set return_sequences=true.
# x = layers.LSTM( )(x) # Add 2nd layer of LSTM with 128 hidden states (aka units)
# outputs = layers.Dense( )(x) # Add a classifier with units=1 and activation="sigmoid"

### Clear cached model to refresh memory and build new model for training ###
keras.backend.clear_session() # Clear cached model
# model = keras.Model(inputs, outputs) # Build new keras model
# model.summary() # Print out model summary

# model.compile( ) # Compile built model with "adam", "binary_crossentropy", and metrics=["accuracy"]
# model.fit( ) # Train the compiled model using model.fit() with batch_size=64, epochs=10, and validation_data=(x_val, y_val)

# %%
########################### Scenario 3 ###########################
##################################################################

### Set random seed to ensure deterministic results ###
import os
seed_value = 1
os.environ['PYTHONHASHSEED']=str(seed_value)
def reset_random_seeds():
   tf.random.set_seed(seed_value)
   np.random.seed(seed_value)
   random.seed(seed_value)

reset_random_seeds() # randomly set initial data

max_features =   # Only consider the top 1k words
maxlen = # Only consider the first 200 words of each movie review

### Model design with Embedding and LSTM layers ####
# inputs = keras.Input(shape=(None,), dtype="int32") # This is an easy way to set an adaptive length for input sequence
# x = layers.Embedding( )(inputs) # Embed data in a 128-dimensional vector
# x = layers.LSTM( )(x) # Add 1st layer of LSTM with 128 hidden states (aka units); set return_sequences=true.
# x = layers.LSTM( )(x) # Add 2nd layer of LSTM with 128 hidden states (aka units)
# outputs = layers.Dense( )(x) # Add a classifier with units=1 and activation="sigmoid"

### Clear cached model to refresh memory and build new model for training ###
keras.backend.clear_session() # Clear cached model
# model = keras.Model(inputs, outputs) # Build new keras model
# model.summary() # Print out model summary

# model.compile( ) # Compile built model with "adam", "binary_crossentropy", and metrics=["accuracy"]
# model.fit( ) # Train the compiled model using model.fit() with batch_size=64, epochs=10, and validation_data=(x_val, y_val)
